# %%
## Bibliotecas e módulos em Python

## Módulos são componentes de código que servem como bibliotecas ou conjunto de funções em Python. Abrigam uma variedade de funcionalidades, incluindo operações matemáticas, interações com o sistema operacional e muitas outras atividades. Módulos representam uma maneira elegante e eficaz de reutilizar código em diferentes partes de um programa ou em projetos distintos.

# %%
#primeiro modo

import math #Biblioteca

math.sqrt(25) #Raiz Quadrada

math.log2(1024) #Logaritmo

math.cos(45) #Cosseno

# %%
#segundo modo

import math as m

m.sqrt(25)
m.log(1024)
m.cos(45)

# %%
#terceiro modo 

from math import  sqrt, log2, cos

sqrt(25)
log2(1024)
cos(45)
# Out:
# 0.5253219888177297

# %%
"""
    Classificação dos módulos (built-in, de terceiros e próprios)

    1. Módulos built-in: embutidos no interpretador.
    
    2. Módulos de tereceiros: criados por terceiros e disponibilizados via PyPl.
    
    3. Módulos próprios: criados pelo desenvolvedor.
    
"""

#Módulos built-in: math; os; svs; Random; datetime; re; collections.

# %%
import matplotlib.pyplot  as plt 

x = [1,2,3,4,5]

y = [2,4,1,3,5]

plt.plot(x , y)

plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

plt.title('Exemplo de Gráfico de Linha')

plt.show()

# %%
#Vamos Exercitar?

import matplotlib.pyplot as plt

meses = ['Janeiro','Fevereiro','Março','Abril','Maio']
vendas = [120,90,150,80,200]

plt.bar(meses, vendas, color='royalblue')

plt.xlabel('Mês')
plt.ylabel('Vendas (em unidades)')

plt.title('Vendas Mensais')

plt.show()
